# %%
import pandas as pd
import numpy as np

# %%
pip install -U mlflow
# Out:
# Requirement already satisfied: mlflow in c:\users\manasa\anaconda3\lib\site-packages (2.13.0)
# Collecting mlflow
#   Downloading mlflow-2.13.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: Flask<4 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (2.2.5)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (2.2.1)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (7.0.0)
# Requirement already satisfied: entrypoints<1 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (0.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (3.1.37)
# Requirement already satisfied: graphene<4 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (3.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (7.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (3.4.1)
# Requirement already satisfied: matplotlib<4 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (3.8.0)
# Requirement already satisfied: numpy<2 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: opentelemetry-api<3,>=1.0.0 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (1.24.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.0.0 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (1.24.0)
# Requirement already satisfied: packaging<25 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (23.2)
# Requirement already satisfied: pandas<3 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (2.2.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (3.20.3)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (14.0.2)
# Requirement already satisfied: pytz<2025 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (2023.3.post1)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (6.0.1)
# Requirement already satisfied: querystring-parser<2 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (2.31.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (1.4.1.post1)
# Requirement already satisfied: scipy<2 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (1.11.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (2.0.25)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (0.5.0)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (3.1.3)
# Requirement already satisfied: waitress<4 in c:\users\manasa\anaconda3\lib\site-packages (from mlflow) (3.0.0)
# Requirement already satisfied: Mako in c:\users\manasa\anaconda3\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in c:\users\manasa\anaconda3\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (4.9.0)
# Requirement already satisfied: colorama in c:\users\manasa\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow) (0.4.6)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\manasa\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.0.7)
# Requirement already satisfied: pywin32>=304 in c:\users\manasa\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (305.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\manasa\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\manasa\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.0.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\manasa\anaconda3\lib\site-packages (from gitpython<4,>=3.1.9->mlflow) (4.0.7)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\manasa\anaconda3\lib\site-packages (from graphene<4->mlflow) (3.2.3)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\manasa\anaconda3\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: aniso8601<10,>=8 in c:\users\manasa\anaconda3\lib\site-packages (from graphene<4->mlflow) (9.0.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\manasa\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\manasa\anaconda3\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\manasa\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\manasa\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\manasa\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\manasa\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\manasa\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\manasa\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\manasa\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\manasa\anaconda3\lib\site-packages (from opentelemetry-api<3,>=1.0.0->mlflow) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in c:\users\manasa\anaconda3\lib\site-packages (from opentelemetry-sdk<3,>=1.0.0->mlflow) (0.45b0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\manasa\anaconda3\lib\site-packages (from pandas<3->mlflow) (2023.3)
# Requirement already satisfied: six in c:\users\manasa\anaconda3\lib\site-packages (from querystring-parser<2->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\manasa\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\manasa\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manasa\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2024.2.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\manasa\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\manasa\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (2.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\manasa\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\manasa\anaconda3\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.0.0->mlflow) (1.14.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\manasa\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow) (4.0.0)
# Downloading mlflow-2.13.1-py3-none-any.whl (25.0 MB)
#    ---------------------------------------- 0.0/25.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/25.0 MB 653.6 kB/s eta 0:00:39
#    ---------------------------------------- 0.1/25.0 MB 1.4 MB/s eta 0:00:18
#    ---------------------------------------- 0.3/25.0 MB 2.0 MB/s eta 0:00:13
#     --------------------------------------- 0.5/25.0 MB 2.6 MB/s eta 0:00:10
#    - -------------------------------------- 0.8/25.0 MB 3.5 MB/s eta 0:00:07
#    - -------------------------------------- 1.2/25.0 MB 4.6 MB/s eta 0:00:06
#    --- ------------------------------------ 2.0/25.0 MB 6.2 MB/s eta 0:00:04
#    --- ------------------------------------ 2.3/25.0 MB 6.0 MB/s eta 0:00:04
#    --- ------------------------------------ 2.3/25.0 MB 5.6 MB/s eta 0:00:05
#    --- ------------------------------------ 2.3/25.0 MB 5.6 MB/s eta 0:00:05
#    --- ------------------------------------ 2.4/25.0 MB 5.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.2/25.0 MB 6.0 MB/s eta 0:00:04
#    ----- ---------------------------------- 3.5/25.0 MB 6.1 MB/s eta 0:00:04
#    ------ --------------------------------- 4.0/25.0 MB 6.4 MB/s eta 0:00:04
#    ------- -------------------------------- 4.5/25.0 MB 6.8 MB/s eta 0:00:04
#    ------- -------------------------------- 4.8/25.0 MB 6.5 MB/s eta 0:00:04
#    ------- -------------------------------- 5.0/25.0 MB 6.5 MB/s eta 0:00:04
#    --------- ------------------------------ 5.9/25.0 MB 7.1 MB/s eta 0:00:03
#    --------- ------------------------------ 6.2/25.0 MB 7.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 6.5/25.0 MB 7.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 7.2/25.0 MB 7.5 MB/s eta 0:00:03
#    ------------ --------------------------- 7.8/25.0 MB 7.6 MB/s eta 0:00:03
#    ------------- -------------------------- 8.4/25.0 MB 8.0 MB/s eta 0:00:03
#    -------------- ------------------------- 9.1/25.0 MB 8.2 MB/s eta 0:00:02
#    --------------- ------------------------ 9.9/25.0 MB 8.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 10.3/25.0 MB 9.0 MB/s eta 0:00:02
#    ------------------ --------------------- 11.3/25.0 MB 10.2 MB/s eta 0:00:02
#    ------------------ --------------------- 11.8/25.0 MB 10.4 MB/s eta 0:00:02
#    -------------------- ------------------- 13.0/25.0 MB 12.6 MB/s eta 0:00:01
#    --------------------- ------------------ 13.7/25.0 MB 12.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 14.6/25.0 MB 13.1 MB/s eta 0:00:01
#    ------------------------ --------------- 15.3/25.0 MB 14.9 MB/s eta 0:00:01
#    ------------------------- -------------- 16.0/25.0 MB 14.6 MB/s eta 0:00:01
#    -------------------------- ------------- 16.9/25.0 MB 16.4 MB/s eta 0:00:01
#    -------------------------- ------------- 16.9/25.0 MB 16.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 18.0/25.0 MB 15.6 MB/s eta 0:00:01
#    ------------------------------ --------- 19.2/25.0 MB 16.8 MB/s eta 0:00:01
#    ------------------------------- -------- 19.9/25.0 MB 16.8 MB/s eta 0:00:01
#    -------------------------------- ------- 20.5/25.0 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 21.7/25.0 MB 18.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 22.3/25.0 MB 17.7 MB/s eta 0:00:01
#    ------------------------------------ --- 22.5/25.0 MB 16.8 MB/s eta 0:00:01
#    ------------------------------------- -- 23.4/25.0 MB 16.0 MB/s eta 0:00:01
#    ------------------------------------- -- 23.6/25.0 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  25.0/25.0 MB 16.4 MB/s eta 0:00:01
#    ---------------------------------------- 25.0/25.0 MB 15.2 MB/s eta 0:00:00
# Installing collected packages: mlflow
#   Attempting uninstall: mlflow
#     Found existing installation: mlflow 2.13.0
#     Uninstalling mlflow-2.13.0:
#       Successfully uninstalled mlflow-2.13.0
# Successfully installed mlflow-2.13.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\manasa\appdata\roaming\python\python311\site-packages (23.3.2)
# Collecting pip
#   Using cached pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.0-py3-none-any.whl (2.1 MB)
# ERROR: To modify pip, please run the following command:
# C:\Users\MANASA\anaconda3\python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_csv("C:\\Users\\MANASA\\Downloads\\Bank_customers_data.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Customer ID', 'Name', 'Surname', 'Gender', 'Age',
#        'Region', 'Job Classification', 'Date Joined', 'Balance', 'loan',
#        'score', 'loan_eligibility'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# Customer ID             int64
# Name                   object
# Surname                object
# Gender                 object
# Age                     int64
# Region                 object
# Job Classification     object
# Date Joined            object
# Balance               float64
# loan                  float64
# score                 float64
# loan_eligibility      float64
# dtype: object

# %% [markdown]
# # Checking null values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Customer ID           0
# Name                  0
# Surname               0
# Gender                0
# Age                   0
# Region                0
# Job Classification    0
# Date Joined           0
# Balance               0
# loan                  0
# score                 0
# loan_eligibility      0
# dtype: int64

# %% [markdown]
# # Seperating data into numerical and categorical columns

# %%
df_num=df.select_dtypes(include=[np.number])

# %%
df_cat=df.select_dtypes(include=["object"])

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns

# %% [markdown]
# # outlier processing of numerical data

# %%
df_num.describe()
# Out:
#         Unnamed: 0   Customer ID          Age        Balance         loan  \
# count  4014.000000  4.014000e+03  4014.000000    4014.000000  4014.000000
# mean   2006.500000  1.696831e+08    38.611111   39766.448274  5557.883159
# std    1158.886319  8.865374e+07     9.819121   29859.489192  2582.640099
# min       0.000000  1.000000e+08    15.000000      11.520000  1000.000000
# 25%    1003.250000  1.000020e+08    31.000000   16115.367500  3366.000000
# 50%    2006.500000  1.000038e+08    37.000000   33567.330000  5566.500000
# 75%    3009.750000  2.000031e+08    45.000000   57533.930000  7768.750000
# max    4013.000000  4.000038e+08    64.000000  183467.700000  9996.000000
#
#              score  loan_eligibility
# count  4014.000000      4.014000e+03
# mean    501.068012      2.100837e+05
# std     113.666117      3.677718e+05
# min     300.000000      0.000000e+00
# 25%     404.000000      0.000000e+00
# 50%     502.000000      3.040905e+04
# 75%     596.750000      2.787510e+05
# max     700.000000      3.633620e+06

# %%
sns.boxplot(df_num[['Age','Balance','loan','score','loan_eligibility']])
# Out:
# <Axes: >

# %%
df_num=df_num[['Age','Balance','loan','score','loan_eligibility']]

# %%
df_num.describe()
# Out:
#                Age        Balance         loan        score  loan_eligibility
# count  4014.000000    4014.000000  4014.000000  4014.000000      4.014000e+03
# mean     38.611111   39766.448274  5557.883159   501.068012      2.100837e+05
# std       9.819121   29859.489192  2582.640099   113.666117      3.677718e+05
# min      15.000000      11.520000  1000.000000   300.000000      0.000000e+00
# 25%      31.000000   16115.367500  3366.000000   404.000000      0.000000e+00
# 50%      37.000000   33567.330000  5566.500000   502.000000      3.040905e+04
# 75%      45.000000   57533.930000  7768.750000   596.750000      2.787510e+05
# max      64.000000  183467.700000  9996.000000   700.000000      3.633620e+06

# %%
q1=0
q3=2.787510e+05
llimt=0
ulimit=2.787510e+05*1.15

# %%
df_num_1=df_num[(df_num["loan_eligibility"]>llimt) & (df_num["loan_eligibility"]<ulimit)]

# %%
sns.boxplot(df_num_1)
# Out:
# <Axes: >

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mms=MinMaxScaler()

# %%
mms.fit(df_num_1)
# Out:
# MinMaxScaler()

# %%
df_num_s=mms.transform(df_num_1)

# %% [markdown]
# # encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df_cat1=df_cat.loc[df_num_1.index.values]

# %%
df_cat_=df_cat1.apply(le.fit_transform)

# %%
df_cat_
# Out:
#       Name  Surname  Gender  Region  Job Classification  Date Joined
# 4       41      109       0       0                   0           72
# 6       46      133       0       0                   0           92
# 9       44      100       1       0                   2          103
# 10      44       72       1       0                   2          103
# 15     119       94       1       0                   2          122
# ...    ...      ...     ...     ...                 ...          ...
# 3988   155       10       1       0                   2          257
# 3991    12       27       1       0                   2          257
# 3992    82      132       1       0                   2          257
# 4004    83       47       1       0                   2          266
# 4006   130       29       0       0                   0          266
#
# [1271 rows x 6 columns]

# %%
pd.DataFrame(df_num_s)
# Out:
#              0         1         2         3         4
# 0     0.487805  0.556861  0.176379  0.263819  0.556861
# 1     0.390244  0.670021  0.182829  0.419598  0.670021
# 2     0.585366  0.170379  0.369996  0.816583  0.682055
# 3     0.536585  0.619818  0.601423  0.404523  0.619818
# 4     0.585366  0.032906  0.471641  0.500000  0.032906
# ...        ...       ...       ...       ...       ...
# 1266  0.195122  0.577562  0.477313  0.419598  0.577562
# 1267  0.000000  0.365549  0.440836  0.419598  0.365549
# 1268  0.268293  0.471182  0.186165  0.180905  0.471182
# 1269  0.658537  0.131671  0.877113  0.703518  0.263522
# 1270  0.390244  0.071111  0.811499  0.693467  0.142401
#
# [1271 rows x 5 columns]

# %%
df_cat_.reset_index(inplace = True)

# %%
df_final=pd.concat([pd.DataFrame(df_num_s),df_cat_],axis=1)

# %%
df_final
# Out:
#              0         1         2         3         4  index  Name  Surname  \
# 0     0.487805  0.556861  0.176379  0.263819  0.556861      4    41      109
# 1     0.390244  0.670021  0.182829  0.419598  0.670021      6    46      133
# 2     0.585366  0.170379  0.369996  0.816583  0.682055      9    44      100
# 3     0.536585  0.619818  0.601423  0.404523  0.619818     10    44       72
# 4     0.585366  0.032906  0.471641  0.500000  0.032906     15   119       94
# ...        ...       ...       ...       ...       ...    ...   ...      ...
# 1266  0.195122  0.577562  0.477313  0.419598  0.577562   3988   155       10
# 1267  0.000000  0.365549  0.440836  0.419598  0.365549   3991    12       27
# 1268  0.268293  0.471182  0.186165  0.180905  0.471182   3992    82      132
# 1269  0.658537  0.131671  0.877113  0.703518  0.263522   4004    83       47
# 1270  0.390244  0.071111  0.811499  0.693467  0.142401   4006   130       29
#
#       Gender  Region  Job Classification  Date Joined
# 0          0       0                   0           72
# 1          0       0                   0           92
# 2          1       0                   2          103
# 3          1       0                   2          103
# 4          1       0                   2          122
# ...      ...     ...                 ...          ...
# 1266       1       0                   2          257
# 1267       1       0                   2          257
# 1268       1       0                   2          257
# 1269       1       0                   2          266
# 1270       0       0                   0          266
#
# [1271 rows x 12 columns]

# %%
df_final.drop(['index','Name','Surname'],axis=1,inplace=True)

# %%
df_final.drop(['Date Joined'],axis=1,inplace=True)

# %%
df_final.head()
# Out:
#           0         1         2         3         4  Gender  Region  \
# 0  0.487805  0.556861  0.176379  0.263819  0.556861       0       0
# 1  0.390244  0.670021  0.182829  0.419598  0.670021       0       0
# 2  0.585366  0.170379  0.369996  0.816583  0.682055       1       0
# 3  0.536585  0.619818  0.601423  0.404523  0.619818       1       0
# 4  0.585366  0.032906  0.471641  0.500000  0.032906       1       0
#
#    Job Classification
# 0                   0
# 1                   0
# 2                   2
# 3                   2
# 4                   2

# %%
df_final.rename(columns={0:'Age',1:'Balance',2:'loan',3:'score',4:'loan_eligibility'},inplace=True)

# %%
df_final.head()
# Out:
#         Age   Balance      loan     score  loan_eligibility  Gender  Region  \
# 0  0.487805  0.556861  0.176379  0.263819          0.556861       0       0
# 1  0.390244  0.670021  0.182829  0.419598          0.670021       0       0
# 2  0.585366  0.170379  0.369996  0.816583          0.682055       1       0
# 3  0.536585  0.619818  0.601423  0.404523          0.619818       1       0
# 4  0.585366  0.032906  0.471641  0.500000          0.032906       1       0
#
#    Job Classification
# 0                   0
# 1                   0
# 2                   2
# 3                   2
# 4                   2

# %%
X=df_final.drop(['loan_eligibility'],axis=1)
y=df_final['loan_eligibility']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=50)

# %%
X_train
# Out:
#            Age   Balance      loan     score  Gender  Region  \
# 175   0.317073  0.100773  0.155138  0.761307       1       0
# 663   0.536585  0.244176  0.267571  0.718593       1       0
# 1232  0.439024  0.075891  0.962189  0.502513       0       0
# 1184  0.219512  0.670364  0.568617  0.190955       0       0
# 990   0.341463  0.426763  0.978425  0.489950       1       0
# ...        ...       ...       ...       ...     ...     ...
# 1268  0.268293  0.471182  0.186165  0.180905       1       0
# 229   0.487805  0.372571  0.290147  0.110553       0       0
# 70    0.341463  0.051254  0.285698  0.394472       0       0
# 132   0.195122  0.230490  0.183052  0.208543       0       0
# 109   0.609756  0.233434  0.930271  0.439698       1       0
#
#       Job Classification
# 175                    0
# 663                    1
# 1232                   2
# 1184                   2
# 990                    0
# ...                  ...
# 1268                   2
# 229                    2
# 70                     1
# 132                    2
# 109                    2
#
# [889 rows x 7 columns]

# %%
y_train
# Out:
# 175     0.403631
# 663     0.488532
# 1232    0.151962
# 1184    0.670364
# 990     0.426763
#           ...
# 1268    0.471182
# 229     0.372571
# 70      0.051254
# 132     0.230490
# 109     0.233434
# Name: loan_eligibility, Length: 889, dtype: float64

# %%
import os
os.environ['GIT_PYTHON_REFRESH']='quiet'
os.environ['MLFLOW_TRACKING_URI']='file:///C://Users//MLOPS'

# %%
import mlflow

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)

# Evaluate the model
predictions = rf.predict(X_test)
accuracy = r2_score(y_test, predictions)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.9954033233626746

# %%
import os
import yaml

# Function to validate tag names
def is_valid_tag_name(tag_name):
    return all(
        c.isalnum() or c in '_-. /' for c in tag_name
    )

# Function to clean up invalid tags from experiment directories
def clean_invalid_tags(experiment_root):
    for root, dirs, files in os.walk(experiment_root):
        for file in files:
            if file == "meta.yaml":
                meta_path = os.path.join(root, file)
                with open(meta_path, 'r') as f:
                    meta_data = yaml.safe_load(f)

                # Check and clean invalid tags
                if 'tags' in meta_data:
                    if isinstance(meta_data['tags'], dict):
                        cleaned_tags = {
                            k: v for k, v in meta_data['tags'].items()
                            if is_valid_tag_name(k)
                        }
                        meta_data['tags'] = cleaned_tags
                    elif isinstance(meta_data['tags'], list):
                        cleaned_tags = [
                            tag for tag in meta_data['tags']
                            if isinstance(tag, dict) and all(is_valid_tag_name(k) for k in tag.keys())
                        ]
                        meta_data['tags'] = cleaned_tags
                    else:
                        # Handle unexpected types in tags
                        meta_data['tags'] = {}

                    with open(meta_path, 'w') as f:
                        yaml.safe_dump(meta_data, f, default_flow_style=False)

# Path to the experiment root directory
experiment_root = "C:/Users/MLOPS"
clean_invalid_tags(experiment_root)

# %%
import os
import yaml
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, filename="cleanup.log", filemode="w",
                    format="%(name)s - %(levelname)s - %(message)s")

# Function to validate tag names
def is_valid_tag_name(tag_name):
    valid = all(c.isalnum() or c in '_-. /' for c in tag_name)
    if not valid:
        logging.warning(f"Invalid tag name detected: {tag_name}")
    return valid

# Function to clean up invalid tags from experiment directories
def clean_invalid_tags(experiment_root):
    # Ensure the .trash directory exists
    trash_dir = os.path.join(experiment_root, '.trash')
    if not os.path.exists(trash_dir):
        os.makedirs(trash_dir)

    for root, dirs, files in os.walk(experiment_root):
        for file in files:
            if file == "meta.yaml":
                meta_path = os.path.join(root, file)
                with open(meta_path, 'r') as f:
                    try:
                        meta_data = yaml.safe_load(f)
                    except yaml.YAMLError as exc:
                        logging.error(f"Error reading {meta_path}: {exc}")
                        continue

                if 'tags' in meta_data:
                    if isinstance(meta_data['tags'], dict):
                        cleaned_tags = {
                            k: v for k, v in meta_data['tags'].items() if is_valid_tag_name(k)
                        }
                        meta_data['tags'] = cleaned_tags
                    elif isinstance(meta_data['tags'], list):
                        cleaned_tags = [
                            tag for tag in meta_data['tags']
                            if isinstance(tag, dict) and all(is_valid_tag_name(k) for k in tag.keys())
                        ]
                        meta_data['tags'] = cleaned_tags
                    else:
                        # Handle unexpected types in tags
                        logging.error(f"Unexpected tags type in {meta_path}: {type(meta_data['tags'])}")
                        meta_data['tags'] = {}

                    with open(meta_path, 'w') as f:
                        try:
                            yaml.safe_dump(meta_data, f, default_flow_style=False)
                        except yaml.YAMLError as exc:
                            logging.error(f"Error writing {meta_path}: {exc}")

# Path to the experiment root directory
experiment_root = "C:/Users/MLOPS"
clean_invalid_tags(experiment_root)

# %%
import mlflow
import mlflow.sklearn

# Log the model with MLflow
mlflow.set_tracking_uri(uri="file:///C:/Users/MLOPS")
#EXPERIMENT_ID = mlflow.create_experiment("ex8",tags={"version":'v1','m1':'rf'})
exp=mlflow.set_experiment(experiment_name="ex8")
with mlflow.start_run():
    mlflow.sklearn.log_model(rf, "random-forest-model")
    mlflow.log_metric("accuracy", accuracy)
# Out:
# 2024/05/23 16:51:42 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: C:\Users\MANASA\AppData\Local\Temp\tmpjv5yvyqu\model\model.pkl, flavor: sklearn). Fall back to return ['scikit-learn==1.4.1.post1', 'cloudpickle==2.2.1']. Set logging level to DEBUG to see the full traceback.

# %%
import requests
import json

#data = {"columns": iris.feature_names, "data": [[6.1, 2.8, 4.7, 1.2]]}
data = {'dataframe_records': X_test.values.tolist()}
headers = {"Content-Type": "application/json"}

response = requests.post("http://localhost:8002/invocations", data=json.dumps(data), headers=headers)
predictions = response.json()

print(predictions)
# Out:
# {'error_code': 'BAD_REQUEST', 'message': 'Encountered an unexpected error while evaluating the model. Verify that the serialized input Dataframe is compatible with the model for inference.', 'stack_trace': 'Traceback (most recent call last):\n  File "C:\\Users\\MANASA\\anaconda3\\Lib\\site-packages\\mlflow\\pyfunc\\scoring_server\\__init__.py", line 367, in invocations\n  File "C:\\Users\\MANASA\\anaconda3\\Lib\\site-packages\\mlflow\\pyfunc\\__init__.py", line 716, in predict\n  File "C:\\Users\\MANASA\\anaconda3\\Lib\\site-packages\\mlflow\\sklearn\\__init__.py", line 543, in predict\n  File "C:\\Users\\MANASA\\anaconda3\\Lib\\site-packages\\sklearn\\ensemble\\_forest.py", line 905, in predict\n    proba = self.predict_proba(X)\n            ^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\MANASA\\anaconda3\\Lib\\site-packages\\sklearn\\ensemble\\_forest.py", line 947, in predict_proba\n    X = self._validate_X_predict(X)\n        ^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\MANASA\\anaconda3\\Lib\\site-packages\\sklearn\\ensemble\\_forest.py", line 641, in _validate_X_predict\n    X = self._validate_data(\n        ^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\MANASA\\anaconda3\\Lib\\site-packages\\sklearn\\base.py", line 654, in _validate_data\n    self._check_n_features(X, reset=reset)\n  File "C:\\Users\\MANASA\\anaconda3\\Lib\\site-packages\\sklearn\\base.py", line 443, in _check_n_features\n    raise ValueError(\nValueError: X has 7 features, but RandomForestClassifier is expecting 11 features as input.\n'}

# %%
predictions["predictions"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 predictions["predictions"]
#
# KeyError: 'predictions'
